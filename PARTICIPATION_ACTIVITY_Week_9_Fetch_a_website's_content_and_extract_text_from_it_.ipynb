# %% [markdown]
# <a href="https://colab.research.google.com/github/Zekaiiz/MSSP-6070-Zekai-Zhang/blob/main/PARTICIPATION_ACTIVITY_Week_9_Fetch_a_website's_content_and_extract_text_from_it_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import requests
from bs4 import BeautifulSoup

def search_flickr(query):
    base_url = "https://www.flickr.com"
    search_url = f"{base_url}/search/?text={query}"

    try:
        response = requests.get(search_url)
        response.raise_for_status()

        soup = BeautifulSoup(response.text, 'html.parser')
        return soup
    except requests.exceptions.RequestException as e:
        print(f"Error: {e}")
        return None

def download_flicker_images (soup, download_dir = "image_downloaded"):
  if soup is None:
    return None
  if not os.path.exists(download_dir):
    os.makedirs(download_dir)

  image_elements = soup.select("img[src]")
  count = 0
  count = 0
  for img in image_elements:
        if count >= max_count:
            break

        src = img.get("src")
        if not src:
            continue


        if src.startswith("//"):
            src = "https:" + src

        if not src.startswith("http"):
            continue
        try:
            print(f"Downloading: {src}")
            res = requests.get(src, timeout=15)
            res.raise_for_status()

            filename = f"img_{count}.jpg"
            filepath = os.path.join(download_dir, filename)

            with open(filepath, "wb") as f:
                f.write(res.content)

            print(f"Saved to {filepath}")
            count += 1

        except Exception as e:
            print(f"Failed to download {src}: {e}")
        return downloaded_paths
